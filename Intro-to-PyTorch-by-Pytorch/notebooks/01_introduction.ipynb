# %% [markdown]
# # 01 · Introduction to PyTorch
#
# Part of the official **Introduction to PyTorch — YouTube Series**.
#
# - 📺 Playlist: https://www.youtube.com/watch?v=IC0_FRiX-sw&list=PL_lsbAsL_o2CTlGHgMxNrKhzP97BaG9ZN
# - 📖 Tutorial: https://docs.pytorch.org/tutorials/beginner/introyt/introyt1_tutorial.html
#
# > Personal notes and experiments while following along. Fill in the cells below as you work through the lesson.

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available:  {torch.cuda.is_available()}")
print(f"MPS available:   {torch.backends.mps.is_available()}")

# %% [markdown]
# ## PyTorch Tensors

# %%
# follow along here

# %% [markdown]
# ## PyTorch Models

# %%
# follow along here

# %% [markdown]
# ## Datasets and Dataloaders

# %%
# follow along here

# %% [markdown]
# ## Training Your PyTorch Model

# %%
# follow along here

# %% [markdown]
# ---
# ### Notes & takeaways
#
# _What clicked, what to revisit:_
