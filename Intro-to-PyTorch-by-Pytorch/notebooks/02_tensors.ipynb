# %% [markdown]
# # 02 · Introduction to PyTorch Tensors
#
# Part of the official **Introduction to PyTorch — YouTube Series**.
#
# - 📺 Playlist: https://www.youtube.com/watch?v=IC0_FRiX-sw&list=PL_lsbAsL_o2CTlGHgMxNrKhzP97BaG9ZN
# - 📖 Tutorial: https://docs.pytorch.org/tutorials/beginner/introyt/tensors_deeper_tutorial.html
#
# > Personal notes and experiments while following along. Fill in the cells below as you work through the lesson.

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available:  {torch.cuda.is_available()}")
print(f"MPS available:   {torch.backends.mps.is_available()}")

# %% [markdown]
# ## Creating Tensors

# %%
# follow along here

# %% [markdown]
# ## Random Tensors and Seeding

# %%
# follow along here

# %% [markdown]
# ## Tensor Shapes

# %%
# follow along here

# %% [markdown]
# ## Tensor Data Types

# %%
# follow along here

# %% [markdown]
# ## Math & Logic with PyTorch Tensors

# %%
# follow along here

# %% [markdown]
# ## Tensor Broadcasting

# %%
# follow along here

# %% [markdown]
# ## More Math with Tensors

# %%
# follow along here

# %% [markdown]
# ## Altering Tensors in Place

# %%
# follow along here

# %% [markdown]
# ## Copying Tensors

# %%
# follow along here

# %% [markdown]
# ## Moving to Accelerator

# %%
# follow along here

# %% [markdown]
# ## Manipulating Tensor Shapes

# %%
# follow along here

# %% [markdown]
# ## Changing the Number of Dimensions

# %%
# follow along here

# %% [markdown]
# ## NumPy Bridge

# %%
# follow along here

# %% [markdown]
# ---
# ### Notes & takeaways
#
# _What clicked, what to revisit:_
