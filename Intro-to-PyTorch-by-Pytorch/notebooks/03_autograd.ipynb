# %% [markdown]
# # 03 · The Fundamentals of Autograd
#
# Part of the official **Introduction to PyTorch — YouTube Series**.
#
# - 📺 Playlist: https://www.youtube.com/watch?v=IC0_FRiX-sw&list=PL_lsbAsL_o2CTlGHgMxNrKhzP97BaG9ZN
# - 📖 Tutorial: https://docs.pytorch.org/tutorials/beginner/introyt/autogradyt_tutorial.html
#
# > Personal notes and experiments while following along. Fill in the cells below as you work through the lesson.

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available:  {torch.cuda.is_available()}")
print(f"MPS available:   {torch.backends.mps.is_available()}")

# %% [markdown]
# ## What Do We Need Autograd For?

# %%
# follow along here

# %% [markdown]
# ## A Simple Example

# %%
# follow along here

# %% [markdown]
# ## Autograd in Training

# %%
# follow along here

# %% [markdown]
# ## Turning Autograd Off and On

# %%
# follow along here

# %% [markdown]
# ## Autograd and In-place Operations

# %%
# follow along here

# %% [markdown]
# ## Autograd Profiler

# %%
# follow along here

# %% [markdown]
# ## More Autograd Detail and the High-Level API

# %%
# follow along here

# %% [markdown]
# ## The High-Level API

# %%
# follow along here

# %% [markdown]
# ---
# ### Notes & takeaways
#
# _What clicked, what to revisit:_
