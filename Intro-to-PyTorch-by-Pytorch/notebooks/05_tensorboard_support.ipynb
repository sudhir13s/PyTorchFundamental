# %% [markdown]
# # 05 · PyTorch TensorBoard Support
#
# Part of the official **Introduction to PyTorch — YouTube Series**.
#
# - 📺 Playlist: https://www.youtube.com/watch?v=IC0_FRiX-sw&list=PL_lsbAsL_o2CTlGHgMxNrKhzP97BaG9ZN
# - 📖 Tutorial: https://docs.pytorch.org/tutorials/beginner/introyt/tensorboardyt_tutorial.html
#
# > Personal notes and experiments while following along. Fill in the cells below as you work through the lesson.

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available:  {torch.cuda.is_available()}")
print(f"MPS available:   {torch.backends.mps.is_available()}")

# %% [markdown]
# ## Before You Start

# %%
# follow along here

# %% [markdown]
# ## Introduction

# %%
# follow along here

# %% [markdown]
# ## Showing Images in TensorBoard

# %%
# follow along here

# %% [markdown]
# ## Graphing Scalars to Visualize Training

# %%
# follow along here

# %% [markdown]
# ## Visualizing Your Model

# %%
# follow along here

# %% [markdown]
# ## Visualizing Your Dataset with Embeddings

# %%
# follow along here

# %% [markdown]
# ## Other Resources

# %%
# follow along here

# %% [markdown]
# ---
# ### Notes & takeaways
#
# _What clicked, what to revisit:_
