# %% [markdown]
# # 06 · Training with PyTorch
#
# Part of the official **Introduction to PyTorch — YouTube Series**.
#
# - 📺 Playlist: https://www.youtube.com/watch?v=IC0_FRiX-sw&list=PL_lsbAsL_o2CTlGHgMxNrKhzP97BaG9ZN
# - 📖 Tutorial: https://docs.pytorch.org/tutorials/beginner/introyt/trainingyt.html
#
# > Personal notes and experiments while following along. Fill in the cells below as you work through the lesson.

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available:  {torch.cuda.is_available()}")
print(f"MPS available:   {torch.backends.mps.is_available()}")

# %% [markdown]
# ## Introduction

# %%
# follow along here

# %% [markdown]
# ## Dataset and DataLoader

# %%
# follow along here

# %% [markdown]
# ## The Model

# %%
# follow along here

# %% [markdown]
# ## Loss Function

# %%
# follow along here

# %% [markdown]
# ## Optimizer

# %%
# follow along here

# %% [markdown]
# ## The Training Loop

# %%
# follow along here

# %% [markdown]
# ## Per-Epoch Activity

# %%
# follow along here

# %% [markdown]
# ## Other Resources

# %%
# follow along here

# %% [markdown]
# ---
# ### Notes & takeaways
#
# _What clicked, what to revisit:_
